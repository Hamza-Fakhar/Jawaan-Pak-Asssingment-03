# %%
#Program to Print Poem
print('''Twinkle,twinkle,little star,\n\tHow I wonder what you are!\n\t\tUp above the world so high\n\t\tLike I a diamond in the sky\nTwinkle,twinkle,little star,\n\tHow I wonder what you are''')
